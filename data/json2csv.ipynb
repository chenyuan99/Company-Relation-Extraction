# %%
import json
train_rel_fre_dict = {}
# file2 = open("nyt10_test_NA.txt", 'w', encoding = 'utf-8')
with open("nyt10_test_NA.txt", 'r', encoding = 'utf-8') as f:
    # for line in f.readlines():
    line = f.readlines()[0]
    temp = json.loads(line)
        # if temp['relation'] == 'NA':
        #     file2.write(line)

# %%
import pandas as pd
with open("nyt10_val_NA.txt", 'r', encoding = 'utf-8') as f:
    df = pd.DataFrame(columns=["text","relation","h","t"])
    for line in f.readlines():
        temp = pd.read_json (line)
        df = df.append(temp)
        print(temp)
# df.to_csv ("nyt10_test_NA.csv", index = None)
df.to_csv ("nyt10_val_NA.csv")
# Out:
#                                           h  \
# id    /guid/9202a8c04000641f80000000000e8a37
# name                              Hicksville
# pos                               [140, 150]
#
#                                            t
# id    /guid/9202a8c04000641f80000000000e3ac5
# name                              Brookhaven
# pos                                 [83, 93]
#                                                    text relation  \
# id    The fastest growing areas for immigrant popula...       NA
# name  The fastest growing areas for immigrant popula...       NA
# pos   The fastest growing areas for immigrant popula...       NA
#
#                                            h  \
# id    /guid/9202a8c04000641f80000000000e8a37
# name                              Hicksville
# pos                               [140, 150]
#
#                                            t
# id    /guid/9202a8c04000641f80000000000e3ac5
# name                              Brookhaven
# ...

# %%
df.to_csv ("nyt10_test_NA2.csv")

# %%
tempjson = pd.read_json (line)
tempjson
# Out:
#                                                    text relation  \
# id    The occasion was suitably exceptional : a reun...       NA
# name  The occasion was suitably exceptional : a reun...       NA
# pos   The occasion was suitably exceptional : a reun...       NA
#
#                                            h  \
# id    /guid/9202a8c04000641f8000000003221072
# name                            Dave Holland
# pos                                [90, 102]
#
#                                            t
# id    /guid/9202a8c04000641f80000000004cfd50
# name                          Barry Altschul
# pos                               [115, 129]

# %%
pip install -U sentence-transformers
# Out:
# ...
#   Using cached sentence-transformers-0.2.6.2.tar.gz (60 kB)
# ...
#   Using cached transformers-2.11.0-py3-none-any.whl (674 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement torch>=1.0.1 (from sentence-transformers) (from versions: 0.1.2, 0.1.2.post1, 0.1.2.post2)
# ERROR: No matching distribution found for torch>=1.0.1 (from sentence-transformers)

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('bert-base-nli-mean-tokens')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c4e037d073ba> in <module>
# ----> 1 from sentence_transformers import SentenceTransformer
#       2 model = SentenceTransformer('bert-base-nli-mean-tokens')
#
# ModuleNotFoundError: No module named 'sentence_transformers'

# %%
import sentence-transformer
# Out:
#   File "<ipython-input-3-bbb9da3c0abb>", line 1
#     import sentence-transformer
#                    ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
with open("nyt10_val_NA.txt", 'r', encoding = 'utf-8') as f:
    df = pd.DataFrame(columns=["text","relation","h","t"])
    for line in f.readlines():
        temp = pd.read_json (line)
        df = df.append(temp)
        print(temp)
# df.to_csv ("nyt10_test_NA.csv", index = None)
df.to_csv ("nyt10_val_NA.csv")

# %%
import pandas as pd
with open("nyt10_train_no_na.txt", 'r', encoding = 'utf-8') as f:
    df = pd.DataFrame(columns=["text","relation","h","t"])
    for line in f.readlines():
        temp = pd.read_json (line)
        df = df.append(temp)
        # print(temp)
# df.to_csv ("nyt10_test_NA.csv", index = None)
df.to_csv ("nyt10_train_no_na.csv")
# Out:
# lation  \
# id    /location/neighborhood/neighborhood_of
# name  /location/neighborhood/neighborhood_of
# pos   /location/neighborhood/neighborhood_of
#
#                                            h  \
# id    /guid/9202a8c04000641f80000000001b2f9f
# name                                 Astoria
# pos                                 [29, 36]
#
#                                            t
# id    /guid/9202a8c04000641f800000000005af5c
# name                                  Queens
# pos                                 [39, 45]
#                                                    text  \
# id    35th Avenue at 36th Street , Astoria , Queens ...
# name  35th Avenue at 36th Street , Astoria , Queens ...
# pos   35th Avenue at 36th Street , Astoria , Queens ...
#
#                                     relation  \
# id    /location/neighborhood/neighborhood_of
# name  /location/neighborhood/neighborhood_of
# pos   /location/neighborhood/neighborhood_of
#
# ...

# %%
df
# Out:
#      type                                               text  \
# id    NaN  Not many people have cooler family closets to ...
# name  NaN  Not many people have cooler family closets to ...
# pos   NaN  Not many people have cooler family closets to ...
# id    NaN  This month Mathew Knowles , father of Beyoncé ...
# name  NaN  This month Mathew Knowles , father of Beyoncé ...
# ...   ...                                                ...
# name  NaN  In Barcelona , Spain , the 1992 Games helped r...
# pos   NaN  In Barcelona , Spain , the 1992 Games helped r...
# id    NaN  It was 1996 , and he had arrived in New York a...
# name  NaN  It was 1996 , and he had arrived in New York a...
# pos   NaN  It was 1996 , and he had arrived in New York a...
#
#                                        relation  \
# id                      /people/person/children
# name                    /people/person/children
# pos                     /people/person/children
# ...
