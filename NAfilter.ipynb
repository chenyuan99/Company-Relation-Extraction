# %%
import json
train_rel_fre_dict = {}
file2 = open("nyt10_test_NA.txt", 'w', encoding = 'utf-8')
with open("nyt10_test.txt", 'r', encoding = 'utf-8') as f:
    for line in f.readlines():
        temp = json.loads(line)
        if temp['relation'] == 'NA':
            file2.write(line)

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('bert-base-nli-mean-tokens')

# %%
sentences = df.text
sentence_embeddings = model.encode(sentences)

# %%
for sentence, embedding in zip(sentences, sentence_embeddings):
    print("Sentence:", sentence)
    print("Embedding:", embedding)
    print("")
# Out:
# 773e-01 -8.48114252e-01  1.47860900e-01
#   4.09886450e-01  1.59995615e-01  8.45300779e-02  3.18580031e-01
#   1.43534794e-01  1.50076538e-01 -8.57980549e-01 -1.02526045e+00
#  -1.00734413e+00  7.45065331e-01  4.26981151e-01  2.91360337e-02
#  -3.10866952e-01  3.53981674e-01  2.72291124e-01  7.74146616e-01
#  -6.93414867e-01 -1.92047462e-01  8.02794099e-01 -1.70293469e-02
#  -8.69855821e-01  3.81247967e-01 -5.90659261e-01  3.47470731e-01
#  -3.62110853e-01 -4.22883064e-01  5.09352863e-01 -4.37398851e-02
#  -6.10394916e-03 -5.36343336e-01 -8.28649521e-01 -7.46487796e-01
#   1.31695569e+00 -2.53788173e-01  3.89137864e-01 -1.03086174e+00
#   1.02879308e-01  4.88632411e-01 -3.01676124e-01 -2.21536592e-01
#  -2.45450646e-01  1.11272287e+00 -7.59408534e-01 -9.63837862e-01
#   7.06247449e-01  2.07371294e-01 -1.01923668e+00  3.25576723e-01
#   1.83344126e-01 -4.41813916e-01  3.40477139e-01 -4.28703189e-01
#  -8.37655738e-02  3.20290357e-01  6.68760896e-01  1.03204176e-01
# ...

# %%
import pandas as pd
with open("nyt10_test_NA.csv", 'r', encoding = 'utf-8') as f:
    df = pd.read_csv (f)
    # print(df.loc[0])

# %%
i = 0
bert = [None] * len(df.text)
for line in df.text:
    sentence_embeddings = model.encode(line)
    bert[i] = str(sentence_embeddings)
    print(bert[i])
    i+=1
df['Bert'] = bert
df.to_csv ("nyt10_val_NA_bert.csv")
# Out:
# 02,
#         2.39169970e-01, -6.89095497e-01,  1.78092718e-01,  1.00090420e+00,
#        -1.40148282e+00,  2.89622456e-01,  1.35290027e-01, -6.16929680e-03,
#         5.24883628e-01,  7.97727466e-01, -3.91872972e-01, -2.76690632e-01,
#        -9.83958125e-01,  3.98874491e-01,  4.17691112e-01,  1.74084201e-01,
#         1.30464888e+00,  4.59731489e-01, -4.49470073e-01, -1.00229490e+00,
#        -8.62605393e-01, -6.95884824e-01, -5.92654467e-01,  7.15314984e-01,
#        -7.20856965e-01,  4.78900164e-01, -1.76173151e-02,  4.22412276e-01,
#        -3.03934336e-01,  5.18344522e-01, -8.44282031e-01, -9.00251031e-01,
#        -8.81715417e-02,  5.49602568e-01, -3.19635630e-01,  4.68933403e-01,
#        -1.11329079e-01,  6.62372947e-01, -3.59006256e-01,  1.05084944e+00,
#        -2.54060805e-01, -2.32352749e-01, -2.38908857e-01, -6.78115040e-02,
#         5.81992149e-01,  4.56307054e-01,  6.93528235e-01, -7.61739016e-01,
# ...

# %%
sentence_embeddings
# Out:
# 1e-01,  4.17691112e-01,  1.74084201e-01,
#          1.30464888e+00,  4.59731489e-01, -4.49470073e-01, -1.00229490e+00,
#         -8.62605393e-01, -6.95884824e-01, -5.92654467e-01,  7.15314984e-01,
#         -7.20856965e-01,  4.78900164e-01, -1.76173151e-02,  4.22412276e-01,
#         -3.03934336e-01,  5.18344522e-01, -8.44282031e-01, -9.00251031e-01,
#         -8.81715417e-02,  5.49602568e-01, -3.19635630e-01,  4.68933403e-01,
#         -1.11329079e-01,  6.62372947e-01, -3.59006256e-01,  1.05084944e+00,
#         -2.54060805e-01, -2.32352749e-01, -2.38908857e-01, -6.78115040e-02,
#          5.81992149e-01,  4.56307054e-01,  6.93528235e-01, -7.61739016e-01,
#         -3.51429820e-01, -1.52600348e-01, -1.25476196e-01,  1.64291620e-01,
#          5.02682567e-01,  1.51075050e-02,  3.45552027e-01, -1.53795630e-01,
#          3.66030991e-01, -4.60987449e-01,  2.93626606e-01, -6.88599348e-02,
#          2.51897871e-01,  1.71961084e-01,  6.30411983e-01, -4.70739938e-02,
# ...

# %%
len(df.text)
# Out:
# 122859

# %%
df['Bert'] = sentence_embeddings

# %%
df.to_csv ("E:\ nyt10_test_NA_bert.csv")
